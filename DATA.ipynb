# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Date":['6/7/25','8/8/25','NaN'],
    "Event":["shopping","marketing","frut saller"],
    "Cost":[2000,3000,1400]
}
df=pd.DataFrame(data)
df
# Out:
#      Date        Event  Cost
# 0  6/7/25     shopping  2000
# 1  8/8/25    marketing  3000
# 2     NaN  frut saller  1400

# %%
n=df["Cost"].mean(),df["Cost"].median(),df["Cost"].mode()
print(n)
# Out:
# (2133.3333333333335, 2000.0, 0    1400
# 1    2000
# 2    3000
# Name: Cost, dtype: int64)

# %%
df["Event"],df["Cost"]
# Out:
# (0       shopping
#  1      marketing
#  2    frut saller
#  Name: Event, dtype: object,
#  0    2000
#  1    3000
#  2    1400
#  Name: Cost, dtype: int64)

# %% [markdown]
# ## ADDING  A TWO NEW COLUMN COUNT AND DISCOUNT

# %%
df["Discount_price"]=df.apply(lambda row:row.Cost - (row.Cost*0.1),axis=1)
df["Discount"]=df.apply(lambda row:row.Cost - row.Discount_price,axis=1)
print(df)
# Out:
#      Date        Event  Cost  Discount_price  Discount
# 0  6/7/25     shopping  2000          1800.0     200.0
# 1  8/8/25    marketing  3000          2700.0     300.0
# 2     NaN  frut saller  1400          1260.0     140.0

# %% [markdown]
# ## ADD TWO MORE EVENTS DATA OBJECTS TO DATASET

# %%
df.loc[len(df.index)]=['13/4/25','vegetables saller',4000,3000,1000]
df.loc[len(df.index)]=['14/5/25','bookshop',400,350,150]
df
# Out:
#       Date              Event  Cost  Discount_price  Discount
# 0   6/7/25           shopping  2000          1800.0     200.0
# 1   8/8/25          marketing  3000          2700.0     300.0
# 2      NaN        frut saller  1400          1260.0     140.0
# 3  13/4/25  vegetables saller  4000          3000.0    1000.0
# 4  14/5/25           bookshop   400           350.0     150.0

# %% [markdown]
# ## MERGING THE  TWO FILE

# %%
import pandas as pd
data={
    "Date":['3/9/25','5/1/25','NaN'],
    "Event":["House rent","Milk rate","water bill"],
    "Cost":[3000,300,NaN]
}
df1=pd.DataFrame(data)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       1 import pandas as pd
#       2 data={
#       3     "Date":['3/9/25','5/1/25','NaN'],
#       4     "Event":["House rent","Milk rate","water bill"],
# ----> 5     "Cost":[3000,300,NaN]
#       6 }
#       7 df1=pd.DataFrame(data)
#       8 df1
#
# NameError: name 'NaN' is not defined

# %%
plt.scatter(df["Cost"],df["Event"])
plt.xlabel("Cost")
plt.ylabel("Event")
plt.title("Scatter plot")
plt.show()

# %%
plt.hist(df["Event"])
plt.title("hisogram of the Table")
plt.show()

# %%
df['Event'].plot(kind='box')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df['Event'].plot(kind='box')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
plt.bar(df["Event"],df["Cost"])
plt.xlabel("Event")
plt.ylabel("Cost")
plt.title("Bar chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["a","b","c","d","e"])
y=np.array([3,5,7,9,2])
plt.plot(x,y)
plt.title("point with specific marks")
plt.show()
