# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/aishwarya m/Downloads/Indian_House_Rent_Dataset.csv")

# %%
df.head()
# Out:
#     Posted On       BHK    Size       Floor    Area Type  \
# 0         NaN       2.0  1100.0         NaN   Super Area
# 1  2022-05-13       2.0   800.0  1 out of 3   Super Area
# 2  2022-05-16       2.0  1000.0  1 out of 3   Super Area
# 3  2022-07-04       2.0   800.0  1 out of 2   Super Area
# 4  2022-05-09  2.0 room   850.0  1 out of 2  Carpet Area
#
#               Area Locality             City Furnishing Status  \
# 0                    Bandel  India-! Kolkata       Unfurnished
# 1  Phool Bagan, Kankurgachi  India-! Kolkata    Semi-Furnished
# 2   Salt Lake City Sector 2  India-- Kolkata    Semi-Furnished
# 3                       NaN              NaN       Unfurnished
# 4             South Dum Dum  India-^ Kolkata       Unfurnished
#
#      Tenant Preferred Bathroom Point of Contact   Rent
# 0  Bach^elors/Fam.ily      2.0    Contact Owner  10000
# 1  Bachelors\/Family*      NaN              NaN  20000
# 2                 NaN      1.0    Contact Owner  17000
# ...

# %%
df.tail()
# Out:
#        Posted On  BHK    Size         Floor    Area Type    Area Locality  \
# 4741  2022-05-18  NaN  1000.0    3 out of 5  Carpet Area     Bandam Kommu
# 4742         NaN  3.0  2000.0    1 out of 4   Super Area              NaN
# 4743  2022-07-10  NaN  1750.0           NaN          NaN              NaN
# 4744  2022-07-06  NaN  1500.0  23 out of 34  Carpet Area       Gachibowli
# 4745  2022-05-04  2.0  1000.0    4 out of 5  Carpet Area  Suchitra Circle
#
#                    City Furnishing Status    Tenant Preferred Bathroom  \
# 4741  India-< Hyderabad    Semi-Furnished  Bachelors/Fa:mily!      2.0
# 4742  India-| Hyderabad    Semi-Furnished  B?achelors,/Family      3.0
# 4743      %-9 Hyderabad    Semi-Furnished  !Bachelors+/Family      3.0
# 4744  India-{ Hyderabad    Semi-Furnished            $Family%      2.0
# 4745      _-9 Hyderabad               NaN         Bachelo%rs:      2.0
#
#      Point of Contact   Rent
# 4741    Contact Owner  15000
# 4742    Contact Owner  29000
# ...

# %%
df.isnull().sum()
# Out:
# Posted On            662
# BHK                  783
# Size                 920
# Floor                786
# Area Type            942
# Area Locality        600
# City                 655
# Furnishing Status    704
# Tenant Preferred     652
# Bathroom             541
# Point of Contact     609
# Rent                   0
# dtype: int64

# %%
m=df['BHK'].mode()
print(m)
# Out:
# 0    2.0
# Name: BHK, dtype: object

# %%
df['BHK']=df['BHK'].fillna(m)
df
# Out:
#        Posted On       BHK    Size         Floor    Area Type  \
# 0            NaN       2.0  1100.0           NaN   Super Area
# 1     2022-05-13       2.0   800.0    1 out of 3   Super Area
# 2     2022-05-16       2.0  1000.0    1 out of 3   Super Area
# 3     2022-07-04       2.0   800.0    1 out of 2   Super Area
# 4     2022-05-09  2.0 room   850.0    1 out of 2  Carpet Area
# ...          ...       ...     ...           ...          ...
# 4741  2022-05-18       1.0  1000.0    3 out of 5  Carpet Area
# 4742         NaN       3.0  2000.0    1 out of 4   Super Area
# 4743  2022-07-10       1.0  1750.0           NaN          NaN
# 4744  2022-07-06       1.0  1500.0  23 out of 34  Carpet Area
# 4745  2022-05-04       2.0  1000.0    4 out of 5  Carpet Area
#
#                  Area Locality               City Furnishing Status  \
# 0                       Bandel    India-! Kolkata       Unfurnished
# 1     Phool Bagan, Kankurgachi    India-! Kolkata    Semi-Furnished
# ...

# %%
df
# Out:
#        Posted On       BHK    Size         Floor    Area Type  \
# 0            NaN       2.0  1100.0           NaN   Super Area
# 1     2022-05-13       2.0   800.0    1 out of 3   Super Area
# 2     2022-05-16       2.0  1000.0    1 out of 3   Super Area
# 3     2022-07-04       2.0   800.0    1 out of 2   Super Area
# 4     2022-05-09  2.0 room   850.0    1 out of 2  Carpet Area
# ...          ...       ...     ...           ...          ...
# 4741  2022-05-18       1.0  1000.0    3 out of 5  Carpet Area
# 4742         NaN       3.0  2000.0    1 out of 4   Super Area
# 4743  2022-07-10       1.0  1750.0           NaN          NaN
# 4744  2022-07-06       1.0  1500.0  23 out of 34  Carpet Area
# 4745  2022-05-04       2.0  1000.0    4 out of 5  Carpet Area
#
#                  Area Locality               City Furnishing Status  \
# 0                       Bandel    India-! Kolkata       Unfurnished
# 1     Phool Bagan, Kankurgachi    India-! Kolkata    Semi-Furnished
# ...

# %%
# Out:
#     Posted On       BHK    Size            Floor    Area Type  \
# 0         NaN       2.0  1100.0              NaN   Super Area
# 1  2022-05-13       2.0   800.0       1 out of 3   Super Area
# 2  2022-05-16       2.0  1000.0       1 out of 3   Super Area
# 3  2022-07-04       2.0   800.0       1 out of 2   Super Area
# 4  2022-05-09  2.0 room   850.0       1 out of 2  Carpet Area
# 5  2022-04-29       2.0   600.0  Ground out of 1   Super Area
#
#               Area Locality             City Furnishing Status  \
# 0                    Bandel  India-! Kolkata       Unfurnished
# 1  Phool Bagan, Kankurgachi  India-! Kolkata    Semi-Furnished
# 2   Salt Lake City Sector 2  India-- Kolkata    Semi-Furnished
# 3                       NaN              NaN       Unfurnished
# 4             South Dum Dum  India-^ Kolkata       Unfurnished
# 5               Thakurpukur  India-\ Kolkata       Unfurnished
#
#      Tenant Preferred Bathroom Point of Contact   Rent
# ...
