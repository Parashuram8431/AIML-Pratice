# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("C:/Users/aishwarya m/Downloads/score.csv")

# %%
df
# Out:
#     Hours  Scores
# 0     2.5    21.0
# 1     5.1    47.0
# 2     3.2    27.0
# 3     8.5    75.0
# 4     3.5    30.0
# 5     1.5    20.0
# 6     9.2    88.0
# 7     5.5    60.0
# 8     8.3    81.0
# 9     2.7    25.0
# 10    7.7    85.0
# 11    5.9    62.0
# 12    4.5    41.0
# 13    3.3    42.0
# 14    1.1    17.0
# 15    8.9    95.0
# 16    2.5    30.0
# 17    1.9    24.0
# 18    6.1    67.0
# 19    7.4    69.0
# 20    2.7    30.0
# 21    4.8    54.0
# 22    3.8    35.0
# 23    6.9    76.0
# 24    7.8    86.0
# 25    8.9     NaN
# 26    6.9     NaN

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    2
# dtype: int64

# %%
df.drop([25,26],inplace=True)

# %%
df
# Out:
#     Hours  Scores
# 0     2.5    21.0
# 1     5.1    47.0
# 2     3.2    27.0
# 3     8.5    75.0
# 4     3.5    30.0
# 5     1.5    20.0
# 6     9.2    88.0
# 7     5.5    60.0
# 8     8.3    81.0
# 9     2.7    25.0
# 10    7.7    85.0
# 11    5.9    62.0
# 12    4.5    41.0
# 13    3.3    42.0
# 14    1.1    17.0
# 15    8.9    95.0
# 16    2.5    30.0
# 17    1.9    24.0
# 18    6.1    67.0
# 19    7.4    69.0
# 20    2.7    30.0
# 21    4.8    54.0
# 22    3.8    35.0
# 23    6.9    76.0
# 24    7.8    86.0

# %%
from sklearn.model_selection import train_test_split
y=df['Scores']
x=df.drop('Scores',axis=1)

# %%
x_train,x_test,y_trian,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
x_train
# Out:
#     Hours
# 21    4.8
# 2     3.2
# 3     8.5
# 1     5.1
# 14    1.1
# 18    6.1
# 0     2.5
# 12    4.5
# 5     1.5
# 23    6.9
# 20    2.7
# 4     3.5
# 8     8.3
# 13    3.3
# 9     2.7
# 15    8.9
# 24    7.8
# 6     9.2
# 17    1.9
# 11    5.9

# %%
y
# Out:
# 0     21.0
# 1     47.0
# 2     27.0
# 3     75.0
# 4     30.0
# 5     20.0
# 6     88.0
# 7     60.0
# 8     81.0
# 9     25.0
# 10    85.0
# 11    62.0
# 12    41.0
# 13    42.0
# 14    17.0
# 15    95.0
# 16    30.0
# 17    24.0
# 18    67.0
# 19    69.0
# 20    30.0
# 21    54.0
# 22    35.0
# 23    76.0
# 24    86.0
# Name: Scores, dtype: float64

# %%
x_test
# Out:
#     Hours
# 16    2.5
# 10    7.7
# 22    3.8
# 19    7.4
# 7     5.5

# %%
x_train.shape,x_test.shape,y_trian.shape,y_test.shape
# Out:
# ((20, 1), (5, 1), (20,), (5,))

# %%
lr= LinearRegression()
model=lr.fit(x_train,y_trian)

# %%
y_pred=model(x_test)
df=pd.DataFrame(['y_trian','y_test','y_pred'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 y_pred=model(x_test)
#       2 df=pd.DataFrame(['y_trian','y_test','y_pred'])
#       3 df
#
# TypeError: 'LinearRegression' object is not callable

# %%
plt.scatter(df["Hours"],df["Scores"],color="orange")
plt.show()
