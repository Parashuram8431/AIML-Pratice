# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/aishwarya m/Documents/Iris.csv")

# %%
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      NaN            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           0.2
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.loc[len(df.index)]=[153,8.9,3.4,5.5,1.3,"Iris_virginica"]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df["Total"]=df["SepalLengthCm"]+df["SepalWidthCm"]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
df["sex]="F"
# Out:
#   Cell In[25], line 1
#     df["sex]="F"
#               ^
# SyntaxError: unterminated f-string literal (detected at line 1)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total qualification
# 0       Iris-setosa    8.6          pass
# 1       Iris-setosa    7.9          pass
# ...

# %%
df["Id"],df["qualification"]
# Out:
# (0        1
#  1        2
#  2        3
#  3        4
#  4        5
#        ...
#  149    150
#  150    153
#  151    153
#  152    153
#  153    153
#  Name: Id, Length: 154, dtype: int64,
#  0      pass
#  1      pass
#  2      pass
#  3      pass
#  4      pass
#         ...
#  149    pass
#  150    pass
#  151    pass
#  152    pass
#  153    pass
#  Name: qualification, Length: 154, dtype: object)

# %%
df

# %%
d=df["SepalLengthCm"].sort_values(ascending=False)

# %%
d
# Out:
# 153    8.9
# 152    8.9
# 151    8.9
# 150    8.9
# 131    7.9
#       ...
# 41     4.5
# 42     4.4
# 38     4.4
# 8      4.4
# 13     4.3
# Name: SepalLengthCm, Length: 154, dtype: float64

# %%
df["qualification"].map(str.upper)
# Out:
# 0      PASS
# 1      PASS
# 2      PASS
# 3      PASS
# 4      PASS
#        ...
# 149    PASS
# 150    PASS
# 151    PASS
# 152    PASS
# 153    PASS
# Name: qualification, Length: 154, dtype: object

# %%
df.drop(["qualification"],axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total qualification
# 0       Iris-setosa    8.6          pass
# 1       Iris-setosa    7.9          pass
# ...

# %%
df.drop(["qualification"],axis=1,inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 149  150            5.9           3.0            5.1           1.8
# 150  153            8.9           3.4            5.5           1.3
# 151  153            8.9           3.4            5.5           1.3
# 152  153            8.9           3.4            5.5           1.3
# 153  153            8.9           3.4            5.5           1.3
#
#             Species  Total
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
d=df["SepalLengthCm"].value_counts()
plt.bar(d.index,d.values)
plt.xlabel("hgff")
plt.ylabel("fdhg")
plt.show()

# %%
df["PetalLengthCm"].plot(kind="box")
# Out:
# <Axes: >

# %%
df.head(8)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  NaN            4.9           3.0            1.4           0.2  Iris-setosa
# 2  3.0            4.7           3.2            1.3           0.2  Iris-setosa
# 3  4.0            4.6           3.1            1.5           0.2  Iris-setosa
# 4  5.0            5.0           3.6            1.4           0.2  Iris-setosa
# 5  NaN            5.4           3.9            1.7           0.4  Iris-setosa
# 6  7.0            4.6           3.4            1.4           0.3  Iris-setosa
# 7  8.0            5.0           3.4            1.5           0.2  Iris-setosa

# %%
df["Id"].mean()
# Out:
# 76.46621621621621

# %%
df["Id"]=df["Id"].fillna(76.46621621621621)

# %%
df
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.000000            5.1           3.5            1.4           0.2
# 1     76.466216            4.9           3.0            1.4           0.2
# 2      3.000000            4.7           3.2            1.3           0.2
# 3      4.000000            4.6           3.1            1.5           0.2
# 4      5.000000            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 145  146.000000            6.7           3.0            5.2           2.3
# 146  147.000000            6.3           2.5            5.0           1.9
# 147  148.000000            6.5           3.0            5.2           2.0
# 148  149.000000            6.2           3.4            5.4           2.3
# 149  150.000000            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
df["Id"].mode()
# Out:
# 0    76.466216
# Name: Id, dtype: float64

# %%
df["Id"]=df["Id"].fillna(76.466216)

# %%
df
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.000000            5.1           3.5            1.4           0.2
# 1     76.466216            4.9           3.0            1.4           0.2
# 2      3.000000            4.7           3.2            1.3           0.2
# 3      4.000000            4.6           3.1            1.5           0.2
# 4      5.000000            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 145  146.000000            6.7           3.0            5.2           2.3
# 146  147.000000            6.3           2.5            5.0           1.9
# 147  148.000000            6.5           3.0            5.2           2.0
# 148  149.000000            6.2           3.4            5.4           2.3
# 149  150.000000            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# ...
