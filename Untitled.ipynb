# %% [markdown]
# Exploratory Data Analysis with Titanic dataset¶

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
test_data=pd.read_csv("C:/Users/aishwarya m/Downloads/test.csv")

# %%
test_data.shape
# Out:
# (418, 11)

# %%
test_data.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sb.countplot(x='Servived',data=train_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 sb.countplot(x='Servived',data=train_data)
#       2 plt.show()
#
# NameError: name 'train_data' is not defined

# %%
test_data.groupby(['Sex', 'Fare'])['Fare'].count()
# Out:
# Sex     Fare
# female  6.9500      1
#         7.0000      1
#         7.2250      1
#         7.2292      2
#         7.2833      1
#                    ..
# male    164.8667    1
#         211.5000    2
#         221.7792    1
#         227.5250    1
#         262.3750    2
# Name: Fare, Length: 216, dtype: int64

# %%
test_data[['Sex','Pclass']].groupby(['Sex']).mean().plot.bar()
sb.countplot(x='Sex',hue='Pclass',data=test_data,)
plt.show()

# %%
sb.countplot(X='Pclass', hue='Embarked', data=test_data)
plt.title('Pclass: Embarked ')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sb.countplot(X='Pclass', hue='Embarked', data=test_data)
#       2 plt.title('Pclass: Embarked ')
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %%
pd.crosstab([test_data.Sex,test_data.PassengerId],test_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# ...

# %%
sb.factorplot(x='Pclass', 'Parch', hue='Sex', data=test_data)
plt.show()
# Out:
#   Cell In[68], line 1
#     sb.factorplot(x='Pclass', 'Parch', hue='Sex', data=test_data)
#                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
print('Oldest person Cabin was of:',test_data['Age'].max())
print('Youngest person Cabin was of:',test_data['Age'].min())
print('Average person Cabin was of:',test_data['Age'].mean())
# Out:
# Oldest person Cabin was of: 76.0
# Youngest person Cabin was of: 0.17
# Average person Cabin was of: 30.272590361445783

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
plt.plot(x='Pclass','Age',hue='Embarked',data=test_data,split=True,ax=ax[0])
ax[0].set_title('PClass and Age vs Embarked')
ax[0].set_yticks(range(0,110,10))
plt.plot(x="Sex","Age", hue="Embarked", data=test_data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Embarked')
ax[1].set_yticks(range(0,110,10))
plt.show()
# Out:
#   Cell In[69], line 2
#     plt.plot(x='Pclass','Age',hue='Embarked',data=test_data,split=True,ax=ax[0])
#                                                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
pd.crosstab(test_data.Initial,test_data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15740\3457658896.py in ?()
# ----> 1 pd.crosstab(test_data.Initial,test_data.Sex).T.style.background_gradient(cmap='summer_r')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Initial'
