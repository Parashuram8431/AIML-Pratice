# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
data={
    "matchs":[00,2,3,4,5],
    "year":[1996,1997,1998,1999,2000],
    "runs":[10,23,15,40,12],
    "balls":[20,30,277777,20,11],
    
}
df=pd.DataFrame(data)
print(df)
# Out:
#    matchs  year  runs   balls
# 0       0  1996    10      20
# 1       2  1997    23      30
# 2       3  1998    15  277777
# 3       4  1999    40      20
# 4       5  2000    12      11

# %%
plt.scatter(df['year'],df['balls'])
plt.xlabel('year')
plt.ylabel('balls')
plt.title('line grap of the student')
plt.show()

# %%
plt.bar(df['matchs'],df['balls'])
plt.xlabel('matchs')
plt.ylabel('balls')
plt.title('NO')
plt.show()

# %%
df.head(2)
# Out:
#    matchs  year  runs  balls
# 0       0  1996    10     20
# 1       2  1997    23     30

# %%
df.isnull().balls()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.isnull().balls()
#
# TypeError: 'Series' object is not callable

# %%
df.shape
# Out:
# (5, 4)

# %%
m=df['year'].mean()
print(m)
# Out:
# 1998.0

# %%
m1=df['balls'].median()
print(m1)
# Out:
# 20.0

# %%
df['matchs']=df['matchs'].fillna()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df['matchs']=df['matchs'].fillna()
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:7293, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7286         if ctr <= ref_count:
#    7287             warnings.warn(
#    7288                 _chained_assignment_warning_method_msg,
#    7289                 FutureWarning,
#    7290                 stacklevel=2,
#    7291             )
# -> 7293 value, method = validate_fillna_kwargs(value, method)
#    7294 if method is not None:
#    7295     warnings.warn(
#    7296         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7297         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)
#    7300         stacklevel=find_stack_level(),
#    7301     )
#
# ...
