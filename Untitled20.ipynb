# %%
import pandas as pd 
df=pd.read_csv('G:/Titanic_Dataset.csv')

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df['name']="gpt"

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone name
# 0    man        True    p  Southampton    no  False  gpt
# 1  woman       False    C    Cherbourg   yes  False  gpt
# 2  woman       False    p  Southampton   yes   True  gpt
# 3  woman       False    C  Southampton   yes  False  gpt
# 4    man        True    p  Southampton    no   True  gpt

# %%
df["Newfare"]=df["fare"]+10

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone name  Newfare
# ...

# %%
df["age catger"]=df["age"].apply (lambda x: "seniars" if x>60 else "juniar")
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone name  Newfare  \
# ...

# %%
df["survived"]=df["survived"].apply (lambda x: "yes" if x==0 else "no")
df
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0        yes       3    male  22.000000      1      0   7.2500        S
# 1         no       1  female  38.000000      1      0  71.2833        C
# 2         no       3  female  26.000000      0      0   7.9250        S
# 3         no       1  female  35.000000      1      0  53.1000        S
# 4        yes       3    male  35.000000      0      0   8.0500        S
# ..       ...     ...     ...        ...    ...    ...      ...      ...
# 886      yes       2    male  27.000000      0      0  13.0000        S
# 887       no       1  female  19.000000      0      0  30.0000        S
# 888      yes       3  female  29.699118      1      2  23.4500        S
# 889       no       1    male  26.000000      0      0  30.0000        C
# 890      yes       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone name  Newfare  \
# ...

# %% [markdown]
# # REMOVE COLUMS

# %% [markdown]
# SINGLE COLUM

# %%
df.drop('Newfare',axis=1)
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0        yes       3    male  22.000000      1      0   7.2500        S
# 1         no       1  female  38.000000      1      0  71.2833        C
# 2         no       3  female  26.000000      0      0   7.9250        S
# 3         no       1  female  35.000000      1      0  53.1000        S
# 4        yes       3    male  35.000000      0      0   8.0500        S
# ..       ...     ...     ...        ...    ...    ...      ...      ...
# 886      yes       2    male  27.000000      0      0  13.0000        S
# 887       no       1  female  19.000000      0      0  30.0000        S
# 888      yes       3  female  29.699118      1      2  23.4500        S
# 889       no       1    male  26.000000      0      0  30.0000        C
# 890      yes       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone name age catger
# ...

# %% [markdown]
# DROP MULTI COLUMS

# %%
df.drop(['pclass','alone'],axis=1,inplace=True)
df.head()
# Out:
#   survived     sex   age  sibsp  parch     fare embarked  class    who  \
# 0      yes    male  22.0      1      0   7.2500        S  Third    man
# 1       no  female  38.0      1      0  71.2833        C  First  woman
# 2       no  female  26.0      0      0   7.9250        S  Third  woman
# 3       no  female  35.0      1      0  53.1000        S  First  woman
# 4      yes    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive name  Newfare age catger
# 0        True    p  Southampton    no  gpt  17.2500     juniar
# 1       False    C    Cherbourg   yes  gpt  81.2833     juniar
# 2       False    p  Southampton   yes  gpt  17.9250     juniar
# 3       False    C  Southampton   yes  gpt  63.1000     juniar
# 4        True    p  Southampton    no  gpt  18.0500     juniar

# %%
df.drop(['sex',	'age',	'sibsp',	'parch',	'fare',	'embarked',	'class'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   survived    who  adult_male deck  embark_town alive name  Newfare age catger
# 0      yes    man        True    p  Southampton    no  gpt  17.2500     juniar
# 1       no  woman       False    C    Cherbourg   yes  gpt  81.2833     juniar
# 2       no  woman       False    p  Southampton   yes  gpt  17.9250     juniar
# 3       no  woman       False    C  Southampton   yes  gpt  63.1000     juniar
# 4      yes    man        True    p  Southampton    no  gpt  18.0500     juniar

# %% [markdown]
# ROW DELITE

# %%
Newrow={"passengersID":12,"survived":"No","pclass":2,"name":"gpt"}
Newrow
# Out:
# {'passengersID': 12, 'survived': 'No', 'pclass': 2, 'name': 'gpt'}

# %%
df
# Out:
#     survived    who  adult_male deck  embark_town alive name  Newfare  \
# 0        yes    man        True    p  Southampton    no  gpt  17.2500
# 1         no  woman       False    C    Cherbourg   yes  gpt  81.2833
# 2         no  woman       False    p  Southampton   yes  gpt  17.9250
# 3         no  woman       False    C  Southampton   yes  gpt  63.1000
# 4        yes    man        True    p  Southampton    no  gpt  18.0500
# ..       ...    ...         ...  ...          ...   ...  ...      ...
# 886      yes    man        True    p  Southampton    no  gpt  23.0000
# 887       no  woman       False    B  Southampton   yes  gpt  40.0000
# 888      yes  woman       False    p  Southampton    no  gpt  33.4500
# 889       no    man        True    C    Cherbourg   yes  gpt  40.0000
# 890      yes    man        True    p   Queenstown    no  gpt  17.7500
#
#     age catger
# 0       juniar
# 1       juniar
# 2       juniar
# 3       juniar
# 4       juniar
# ..         ...
# ...

# %%
df.loc(len(df))==["yes","man","true","p","Queenstown","gpt",11.567,"juniar"]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 891
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10136\483940149.py in ?()
# ----> 1 df.loc(len(df))==["yes","man","true","p","Queenstown","gpt",11.567,"juniar"]
#       2 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...

# %%
df.drop(0)
# Out:
#     survived    who  adult_male deck  embark_town alive name  Newfare  \
# 1         no  woman       False    C    Cherbourg   yes  gpt  81.2833
# 2         no  woman       False    p  Southampton   yes  gpt  17.9250
# 3         no  woman       False    C  Southampton   yes  gpt  63.1000
# 4        yes    man        True    p  Southampton    no  gpt  18.0500
# 5        yes    man        True    p   Queenstown    no  gpt  18.4583
# ..       ...    ...         ...  ...          ...   ...  ...      ...
# 886      yes    man        True    p  Southampton    no  gpt  23.0000
# 887       no  woman       False    B  Southampton   yes  gpt  40.0000
# 888      yes  woman       False    p  Southampton    no  gpt  33.4500
# 889       no    man        True    C    Cherbourg   yes  gpt  40.0000
# 890      yes    man        True    p   Queenstown    no  gpt  17.7500
#
#     age catger
# 1       juniar
# 2       juniar
# 3       juniar
# 4       juniar
# 5       juniar
# ..         ...
# ...

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df=df[df["name"]=="gpt"]
df
# Out:
#     survived    who  adult_male deck  embark_town alive name  Newfare  \
# 0        yes    man        True    p  Southampton    no  gpt  17.2500
# 1         no  woman       False    C    Cherbourg   yes  gpt  81.2833
# 2         no  woman       False    p  Southampton   yes  gpt  17.9250
# 3         no  woman       False    C  Southampton   yes  gpt  63.1000
# 4        yes    man        True    p  Southampton    no  gpt  18.0500
# ..       ...    ...         ...  ...          ...   ...  ...      ...
# 886      yes    man        True    p  Southampton    no  gpt  23.0000
# 887       no  woman       False    B  Southampton   yes  gpt  40.0000
# 888      yes  woman       False    p  Southampton    no  gpt  33.4500
# 889       no    man        True    C    Cherbourg   yes  gpt  40.0000
# 890      yes    man        True    p   Queenstown    no  gpt  17.7500
#
#     age catger
# 0       juniar
# 1       juniar
# 2       juniar
# 3       juniar
# 4       juniar
# ..         ...
# ...

# %%
# Out:
#     survived    who  adult_male deck  embark_town alive name  Newfare  \
# 0        yes    man        True    p  Southampton    no  gpt  17.2500
# 1         no  woman       False    C    Cherbourg   yes  gpt  81.2833
# 2         no  woman       False    p  Southampton   yes  gpt  17.9250
# 3         no  woman       False    C  Southampton   yes  gpt  63.1000
# 4        yes    man        True    p  Southampton    no  gpt  18.0500
# ..       ...    ...         ...  ...          ...   ...  ...      ...
# 886      yes    man        True    p  Southampton    no  gpt  23.0000
# 887       no  woman       False    B  Southampton   yes  gpt  40.0000
# 888      yes  woman       False    p  Southampton    no  gpt  33.4500
# 889       no    man        True    C    Cherbourg   yes  gpt  40.0000
# 890      yes    man        True    p   Queenstown    no  gpt  17.7500
#
#     age catger
# 0       juniar
# 1       juniar
# 2       juniar
# 3       juniar
# 4       juniar
# ..         ...
# ...

# %%
df.isnull().sum()
# Out:
# survived       0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# name           0
# Newfare        0
# age catger     0
# dtype: int64

# %%
df=df[df["survived"]!="NaN"]

# %%
df.head()
# Out:
#   survived    who  adult_male deck  embark_town alive name  Newfare age catger
# 0      yes    man        True    p  Southampton    no  gpt  17.2500     juniar
# 1       no  woman       False    C    Cherbourg   yes  gpt  81.2833     juniar
# 2       no  woman       False    p  Southampton   yes  gpt  17.9250     juniar
# 3       no  woman       False    C  Southampton   yes  gpt  63.1000     juniar
# 4      yes    man        True    p  Southampton    no  gpt  18.0500     juniar

# %%
df=df.dropna()
