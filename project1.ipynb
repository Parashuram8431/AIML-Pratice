# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set style of visualization
sns.set_style("whitegrid")
sns.set_palette("RdBu")

# %%
df=pd.read_csv("E:/Student_Performance.csv")

# %%
df
# Out:
#            Name   Age Sex  Hours Studied  Previous Scores  \
# 0        Adarsh  18.0   M              7               99
# 1         Akash  17.0   M              4               82
# 2         Amith  12.0   M              8               51
# 3        Anusha  15.0   F              5               52
# 4        Ananya  27.0   F              7               75
# 5       Ankitha  18.0   F              3               78
# 6      Aswhvini  17.0   F              7               73
# 7      Bhargavi  20.0   F              8               45
# 8       Bhvavna  23.0   F              5               77
# 9       Boomika  24.0   F              4               89
# 10      Chithra  22.0   F              8               91
# 11  Chandrakala  23.0   F              8               79
# 12       Charan  19.0   M              3               60
# 13     Danajaya  26.0   M              6               47
# 14        Divya  18.0   F              5               79
# ...

# %% [markdown]
# # 1 See the top five rows

# %%
df.head(8)
# Out:
#        Name   Age Sex  Hours Studied  Previous Scores  \
# 0    Adarsh  18.0   M              7               99
# 1     Akash  17.0   M              4               82
# 2     Amith  12.0   M              8               51
# 3    Anusha  15.0   F              5               52
# 4    Ananya  27.0   F              7               75
# 5   Ankitha  18.0   F              3               78
# 6  Aswhvini  17.0   F              7               73
# 7  Bhargavi  20.0   F              8               45
#
#   Extracurricular Activities  Sleep Hours  Sample Question Papers Practiced  \
# 0                        Yes            9                                 1
# 1                         No            4                                 2
# 2                        Yes            7                                 2
# 3                        Yes            5                                 2
# 4                         No            8                                 5
# ...

# %% [markdown]
# # See the last five rows

# %%
df.tail()
# Out:
#         Name   Age Sex  Hours Studied  Previous Scores  \
# 50  Rakesh s  26.0   M              4               44
# 51  Sreyanka  24.0   F              2               89
# 52    Soumya  22.0   F              6               81
# 53   Shrusti  18.0   F              6               62
# 54  Sushitha  18.0   F              4               93
#
#    Extracurricular Activities  Sleep Hours  Sample Question Papers Practiced  \
# 50                        Yes            7                                 6
# 51                        Yes            6                                 1
# 52                         No            9                                 9
# 53                        Yes            9                                 0
# 54                         No            8                                 3
#
#     Performance Index
# 50                 27
# 51                 65
# 52                 75
# 53                 52
# 54                 78

# %% [markdown]
# # show the size of dataframe

# %%
df.shape
# Out:
# (55, 9)

# %% [markdown]
# # 2 See column data type and some info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Name                              55 non-null     object
#  1   Age                               53 non-null     float64
#  2   Sex                               55 non-null     object
#  3   Hours Studied                     55 non-null     int64
#  4   Previous Scores                   55 non-null     int64
#  5   Extracurricular Activities        55 non-null     object
#  6   Sleep Hours                       55 non-null     int64
#  7   Sample Question Papers Practiced  55 non-null     int64
#  8   Performance Index                 55 non-null     int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# # show the statistical info

# %%
df.describe()
# Out:
#              Age  Hours Studied  Previous Scores  Sleep Hours  \
# count  53.000000      55.000000        55.000000    55.000000
# mean   23.886792       5.127273        71.400000     6.509091
# std     8.368118       2.427120        15.630692     1.804036
# min    12.000000       1.000000        43.000000     4.000000
# 25%    19.000000       3.000000        61.000000     5.000000
# 50%    23.000000       5.000000        73.000000     7.000000
# 75%    26.000000       7.000000        81.500000     8.000000
# max    67.000000       9.000000        99.000000     9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                         55.000000          55.000000
# mean                           3.454545          57.545455
# std                            2.522625          16.720821
# min                            0.000000          17.000000
# 25%                            2.000000          44.000000
# ...

# %% [markdown]
# # 3 See precentege of missing value in each column

# %%
df.isnull().sum()
# Out:
# Name                                0
# Age                                 2
# Sex                                 0
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# # Filling the missing values using mean

# %%
a=df['Age'].mean()
a
# Out:
# 23.88679245283019

# %%
df['Age']=df['Age'].fillna(a)
df
# Out:
#            Name        Age Sex  Hours Studied  Previous Scores  \
# 0        Adarsh  18.000000   M              7               99
# 1         Akash  17.000000   M              4               82
# 2         Amith  12.000000   M              8               51
# 3        Anusha  15.000000   F              5               52
# 4        Ananya  27.000000   F              7               75
# 5       Ankitha  18.000000   F              3               78
# 6      Aswhvini  17.000000   F              7               73
# 7      Bhargavi  20.000000   F              8               45
# 8       Bhvavna  23.000000   F              5               77
# 9       Boomika  24.000000   F              4               89
# 10      Chithra  22.000000   F              8               91
# 11  Chandrakala  23.000000   F              8               79
# 12       Charan  19.000000   M              3               60
# 13     Danajaya  26.000000   M              6               47
# ...

# %%
df.isnull().sum()
# Out:
# Name                                0
# Age                                 0
# Sex                                 0
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# # 5 Check if duplicated in data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 7 See quick info of category values

# %%
df.describe(include = object)
# Out:
#           Name Sex Extracurricular Activities
# count       55  55                         55
# unique      55   2                          2
# top     Adarsh   M                        Yes
# freq         1  28                         30

# %% [markdown]
#  # Exploring whether there are wrong categorical values

# %%
df.Age.value_counts(ascending=False)
# Out:
# Age
# 18.000000    7
# 26.000000    6
# 22.000000    5
# 19.000000    4
# 25.000000    4
# 23.000000    3
# 24.000000    3
# 12.000000    3
# 20.000000    2
# 29.000000    2
# 35.000000    2
# 28.000000    2
# 17.000000    2
# 23.886792    2
# 40.000000    1
# 67.000000    1
# 21.000000    1
# 15.000000    1
# 27.000000    1
# 31.000000    1
# 32.000000    1
# 30.000000    1
# Name: count, dtype: int64

# %%
df.loc[df.Age.isin([18,22,26,19,23])]
# Out:
#            Name   Age Sex  Hours Studied  Previous Scores  \
# 0        Adarsh  18.0   M              7               99
# 5       Ankitha  18.0   F              3               78
# 8       Bhvavna  23.0   F              5               77
# 10      Chithra  22.0   F              8               91
# 11  Chandrakala  23.0   F              8               79
# 12       Charan  19.0   M              3               60
# 13     Danajaya  26.0   M              6               47
# 14        Divya  18.0   F              5               79
# 16   Guru kiran  18.0   M              8               73
# 17      Harisha  19.0   M              6               83
# 18       Harsha  18.0   M              2               54
# 19      Karthik  22.0   M              5               75
# 21        Kiran  19.0   M              6               96
# 23        Madan  23.0   M              1               85
# 26      Mamatha  26.0   F              4               79
# ...

# %% [markdown]
# # To add the Total coloumn to sleeping hours and Performance index

# %%
add=df['Total']=df['Sleep Hours']+df['Performance Index']
print(add)
# Out:
# 0     100
# 1      69
# 2      52
# 3      41
# 4      74
# 5      70
# 6      68
# 7      46
# 8      69
# 9      73
# 10     88
# 11     79
# 12     75
# 13     37
# 14     75
# 15     47
# 16     75
# 17     77
# 18     34
# 19     70
# 20     75
# 21     94
# 22     80
# 23     62
# 24     41
# 25     56
# 26     74
# 27     89
# 28     80
# 29     78
# 30     46
# 31     45
# 32     64
# 33     55
# 34     69
# 35     83
# 36     50
# 37     76
# 38     36
# 39     69
# 40     52
# 41     45
# 42     65
# 43     45
# 44     77
# 45     58
# 46     24
# 47     58
# 48     62
# 49     60
# 50     34
# 51     71
# 52     84
# 53     61
# 54     86
# dtype: int64

# %% [markdown]
# # some Questions for this dataset

# %% [markdown]
# #1 What is the av age of the students

# %%
df['Age'].mean()
# Out:
# 23.886792452830186

# %% [markdown]
# # 2 How many male and female students are there

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    28
# F    27
# Name: count, dtype: int64

# %% [markdown]
# # 3 what is the total performance score of each student

# %%
df['Total']=df['Performance Index']+df['Sample Question Papers Practiced']
df[['Name','Total']]
# Out:
#            Name  Total
# 0        Adarsh     92
# 1         Akash     67
# 2         Amith     47
# 3        Anusha     38
# 4        Ananya     71
# 5       Ankitha     67
# 6      Aswhvini     69
# 7      Bhargavi     48
# 8       Bhvavna     63
# 9       Boomika     69
# 10      Chithra     89
# 11  Chandrakala     75
# 12       Charan     68
# 13     Danajaya     35
# 14        Divya     76
# 15      Goutham     46
# 16   Guru kiran     71
# 17      Harisha     72
# 18       Harsha     39
# 19      Karthik     63
# 20     Kerthana     74
# 21        Kiran     85
# 22     Kruthika     79
# 23        Madan     63
# 24      Madan R     38
# 25    M  Atheef     53
# 26      Mamatha     75
# 27     Maniknta     89
# 28       Naveen     79
# 29      Mhethab     77
# 30       Monika     42
# 31       Nayana     37
# 32      Nithaya     67
# 33    Omprakash     48
# 34   Parashuram     63
# 35       Pramod     78
# 36       Preeti     45
# 37       Rakesh     70
# 38    Rakesh mb     33
# ...

# %% [markdown]
# # 4 Which student studied the most hours

# %%
df.loc[df['Hours Studied'].idxmax()]
# Out:
# Name                                Kruthika
# Age                                     25.0
# Sex                                        F
# Hours Studied                              9
# Previous Scores                           74
# Extracurricular Activities               Yes
# Sleep Hours                                7
# Sample Question Papers Practiced           6
# Performance Index                         73
# Total                                     79
# Name: 22, dtype: object

# %% [markdown]
# # Which student studied the most hours

# %%
df.loc[df['Hours Studied'].idxmin()]
# Out:
# Name                                Kerthana
# Age                                     25.0
# Sex                                        F
# Hours Studied                              1
# Previous Scores                           99
# Extracurricular Activities               Yes
# Sleep Hours                                4
# Sample Question Papers Practiced           3
# Performance Index                         71
# Total                                     74
# Name: 20, dtype: object

# %% [markdown]
# # 5 Show student who scored above 60 in performance

# %%
df[df['Performance Index']>65]
# Out:
#            Name   Age Sex  Hours Studied  Previous Scores  \
# 0        Adarsh  18.0   M              7               99
# 4        Ananya  27.0   F              7               75
# 9       Boomika  24.0   F              4               89
# 10      Chithra  22.0   F              8               91
# 11  Chandrakala  23.0   F              8               79
# 12       Charan  19.0   M              3               60
# 14        Divya  18.0   F              5               79
# 16   Guru kiran  18.0   M              8               73
# 17      Harisha  19.0   M              6               83
# 20     Kerthana  25.0   F              1               99
# 21        Kiran  19.0   M              6               96
# 22     Kruthika  25.0   F              9               74
# 26      Mamatha  26.0   F              4               79
# 27     Maniknta  26.0   M              9               84
# 28       Naveen  67.0   M              3               94
# ...

# %% [markdown]
# # Checking the outliers

# %%
df["Age"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Replace the outliers using IQR method

# %%
q1=df['Age'].quantile(0.25)
q3=df['Age'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr)
bat_arr=df['Age']
out=bat_arr[(bat_arr<=lower_bound)|(bat_arr>=upper_bound)]
print(out)
# Out:
# 24    40.0
# 28    67.0
# Name: Age, dtype: float64

# %%
ba_arr=df['Age']
lower_cap=np.percentile(ba_arr,0)
upper_cap=np.percentile(ba_arr,65)
for i in df['Age']:
    if i <lower_bound:
        df['Age']=df['Age'].replace(i,lower_cap)
    elif i >upper_bound:
        df['Age']=df['Age'].replace(i,upper_cap)

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # bar graph

# %%
b=(df['Age'].value_counts())
b
# Out:
# Age
# 18.000000    7
# 25.000000    6
# 26.000000    6
# 22.000000    5
# 19.000000    4
# 12.000000    3
# 23.000000    3
# 24.000000    3
# 28.000000    2
# 29.000000    2
# 35.000000    2
# 23.886792    2
# 17.000000    2
# 20.000000    2
# 27.000000    1
# 21.000000    1
# 31.000000    1
# 32.000000    1
# 30.000000    1
# 15.000000    1
# Name: count, dtype: int64

# %%
plt.bar(b.index,b.values)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# # Pie chart

# %%
c=df['Sex'].value_counts().sort_index()
c
# Out:
# Sex
# F    27
# M    28
# Name: count, dtype: int64

# %%
bc=df['Sex'].value_counts()
plt.pie(bc,labels=bc.index,autopct='%1.1f%%')
plt.legend(labels=bc.index,title='Sex',loc='best')
plt.title('sex distibution')
plt.show()

# %% [markdown]
# # line graph

# %%
df['Hours Studied'].unique()
# Out:
# array([7, 4, 8, 5, 3, 6, 2, 1, 9], dtype=int64)

# %%
rc=df.groupby('Hours Studied').size()
plt.plot(rc.index,rc.values,marker='o')
plt.xlabel("Hours Studied")
plt.ylabel('counts')
plt.title("Hours Studied distribution")
plt.show()

# %% [markdown]
# # scatter plot

# %%
c=df['Performance Index'].value_counts()
plt.scatter(c.index,c.values)
plt.xlabel("Performance Index")
plt.ylabel('counts')
plt.title('Performance Index of scatter plot')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Performance Index'])
plt.xlabel("Performance Index")
plt.ylabel('counts')
plt.title('distribution of performance index')
plt.show()

# %% [markdown]
# # drop te column

# %%
df.drop(['Extracurricular Activities'],axis=1)
# Out:
#            Name   Age Sex  Hours Studied  Previous Scores  Sleep Hours  \
# 0        Adarsh  18.0   M              7               99            9
# 1         Akash  17.0   M              4               82            4
# 2         Amith  12.0   M              8               51            7
# 3        Anusha  15.0   F              5               52            5
# 4        Ananya  27.0   F              7               75            8
# 5       Ankitha  18.0   F              3               78            9
# 6      Aswhvini  17.0   F              7               73            5
# 7      Bhargavi  20.0   F              8               45            4
# 8       Bhvavna  23.0   F              5               77            8
# 9       Boomika  24.0   F              4               89            4
# 10      Chithra  22.0   F              8               91            4
# 11  Chandrakala  23.0   F              8               79            6
# ...

# %%
df
# Out:
#            Name   Age Sex  Hours Studied  Previous Scores  \
# 0        Adarsh  18.0   M              7               99
# 1         Akash  17.0   M              4               82
# 2         Amith  12.0   M              8               51
# 3        Anusha  15.0   F              5               52
# 4        Ananya  27.0   F              7               75
# 5       Ankitha  18.0   F              3               78
# 6      Aswhvini  17.0   F              7               73
# 7      Bhargavi  20.0   F              8               45
# 8       Bhvavna  23.0   F              5               77
# 9       Boomika  24.0   F              4               89
# 10      Chithra  22.0   F              8               91
# 11  Chandrakala  23.0   F              8               79
# 12       Charan  19.0   M              3               60
# 13     Danajaya  26.0   M              6               47
# 14        Divya  18.0   F              5               79
# ...

# %%
# import libraries to model

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

# %%
# create object from labelencoder

encoder = LabelEncoder()

df["Extracurricular Activities"] =  encoder.fit_transform(df["Extracurricular Activities"])

# %%
# see sample of data

df.sample(2)
# Out:
#        Name   Age Sex  Hours Studied  Previous Scores  \
# 24  Madan R  40.0   M              3               61
# 26  Mamatha  26.0   F              4               79
#
#     Extracurricular Activities  Sleep Hours  Sample Question Papers Practiced  \
# 24                           0            6                                 3
# 26                           0            8                                 9
#
#     Performance Index
# 24                 35
# 26                 66

# %%
# Splitting data into Indipendent and Dependent Variable

X= df.drop(columns = "Performance Index")
Y= df["Performance Index"]

# %%
# see sample of train data

X.sample(3)
# Out:
#          Name   Age Sex  Hours Studied  Previous Scores  \
# 41    Sanjana  29.0   F              2               63
# 25  M  Atheef  28.0   M              7               62
# 0      Adarsh  18.0   M              7               99
#
#     Extracurricular Activities  Sleep Hours  Sample Question Papers Practiced
# 41                           1            6                                 0
# 25                           1            7                                 4
# 0                            1            9                                 1

# %%
# see sample of target label

Y
# Out:
# 0     91
# 1     65
# 2     45
# 3     36
# 4     66
# 5     61
# 6     63
# 7     42
# 8     61
# 9     69
# 10    84
# 11    73
# 12    66
# 13    33
# 14    68
# 15    43
# 16    67
# 17    70
# 18    30
# 19    63
# 20    71
# 21    85
# 22    73
# 23    57
# 24    35
# 25    49
# 26    66
# 27    83
# 28    74
# 29    74
# 30    39
# 31    36
# 32    58
# 33    47
# 34    60
# 35    74
# 36    42
# 37    68
# 38    32
# 39    64
# 40    45
# 41    39
# 42    58
# 43    36
# 44    71
# 45    54
# 46    17
# 47    54
# 48    58
# 49    53
# 50    27
# 51    65
# 52    75
# 53    52
# 54    78
# Name: Performance Index, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
# see shape of splited data

print("x_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("x_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (44, 8)
# y_train shape:  (44,)
# x_test shape:  (11, 8)
# y_test shape:  (11,)

# %% [markdown]
# # Modeling

# %%
# create object from RandomForestRegressor

model = LinearRegression()

# %%
# fit model

model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1744\3153487682.py in ?()
#       1 # fit model
#       2
# ----> 3 model.fit(X_train,y_train)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     574         n_jobs_ = self.n_jobs
#     575
#     576         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     577
# --> 578         X, y = self._validate_data(
# ...
