# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/aishwarya m/Downloads/indian_House_Rent_Dataset.csv")

# %%
df
# Out:
#        Posted On       BHK    Size         Floor    Area Type  \
# 0            NaN       2.0  1100.0           NaN   Super Area
# 1     2022-05-13       2.0   800.0    1 out of 3   Super Area
# 2     2022-05-16       2.0  1000.0    1 out of 3   Super Area
# 3     2022-07-04       2.0   800.0    1 out of 2   Super Area
# 4     2022-05-09  2.0 room   850.0    1 out of 2  Carpet Area
# ...          ...       ...     ...           ...          ...
# 4741  2022-05-18       NaN  1000.0    3 out of 5  Carpet Area
# 4742         NaN       3.0  2000.0    1 out of 4   Super Area
# 4743  2022-07-10       NaN  1750.0           NaN          NaN
# 4744  2022-07-06       NaN  1500.0  23 out of 34  Carpet Area
# 4745  2022-05-04       2.0  1000.0    4 out of 5  Carpet Area
#
#                  Area Locality               City Furnishing Status  \
# 0                       Bandel    India-! Kolkata       Unfurnished
# 1     Phool Bagan, Kankurgachi    India-! Kolkata    Semi-Furnished
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/aishwarya m/Documents/titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.scatter(df["survived"],df["pclass"])
plt.xlabel("survived")
plt.ylabel("pclass")
plt.title("scatter plot")
plt.show()

# %%
plt.hist(df["survived"])
plt.title("histogram of the exp")
plt.show()

# %%
plt.boxplot(df["pclass"])
plt.title("boxplot")
plt.show()

# %%
plt.bar(df["survived"],df["pclass"])
plt.xlabel("survived")
plt.ylabel("pclass")
plt.title("Bar graph")
plt.show()

# %%
df.plot("survived","pclass",kind="box")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.array([1,2,3,4,5,6])
y=np.array(["a","b","c","d","e","f"])
plt.title("plot")
plt.plot(x,y)
plt.show()

# %%
df["Total"]=df["survived"]+df["pclass"]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df["qualification"]=df["sibsp"]+df["fare"]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(["qualification"],axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(["qualification"],axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.loc[len(df.index)]=[892,3,2,"male",23.1,0,5.5600,"Q","First","man","true","NAN","ffhkkdmfdrm","no","true",6]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0    1.0      0   7.2500        S  Third
# 1           1       1  female  38.0    1.0      0  71.2833        C  First
# 2           1       3  female  26.0    0.0      0   7.9250        S  Third
# 3           1       1  female  35.0    1.0      0  53.1000        S  First
# 4           0       3    male  35.0    0.0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 887         1       1  female  19.0    0.0      0  30.0000        S  First
# 888         0       3  female   NaN    1.0      2  23.4500        S  Third
# 889         1       1    male  26.0    0.0      0  30.0000        C  First
# 890         0       3    male  32.0    0.0      0   7.7500        Q  Third
# 891       892       3       2  male   23.1      0   5.5600        Q  First
#
#        who adult_male deck  embark_town alive  alone  Total
# ...

# %%
df["fare"],df["sex"]
# Out:
# (0       7.2500
#  1      71.2833
#  2       7.9250
#  3      53.1000
#  4       8.0500
#          ...
#  887    30.0000
#  888    23.4500
#  889    30.0000
#  890     7.7500
#  891     5.5600
#  Name: fare, Length: 892, dtype: float64,
#  0        male
#  1      female
#  2      female
#  3      female
#  4        male
#          ...
#  887    female
#  888    female
#  889      male
#  890      male
#  891         2
#  Name: sex, Length: 892, dtype: object)

# %%
d=df["fare"].sort_values(ascending=True)
d
# Out:
# 263      0.0000
# 481      0.0000
# 413      0.0000
# 597      0.0000
# 302      0.0000
#          ...
# 341    263.0000
# 88     263.0000
# 737    512.3292
# 258    512.3292
# 679    512.3292
# Name: fare, Length: 892, dtype: float64

# %%
d=(df[df["sex"]=="f"])
d
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone, Total]
# Index: []

# %%
d=df["embark_town"].map(str.upper)
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 d=df["embark_town"].map(str.upper)
#       2 d
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0    1.0      0   7.2500        S  Third
# 1         1       1  female  38.0    1.0      0  71.2833        C  First
# 2         1       3  female  26.0    0.0      0   7.9250        S  Third
# 3         1       1  female  35.0    1.0      0  53.1000        S  First
# 4         0       3    male  35.0    0.0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone  Total
# 0    man       True  NaN  Southampton    no  False      3
# 1  woman      False    C    Cherbourg   yes  False      2
# 2  woman      False  NaN  Southampton   yes   True      4
# 3  woman      False    C  Southampton   yes  False      2
# 4    man       True  NaN  Southampton    no   True      3

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 887         1       1  female  19.0    0.0      0  30.00        S  First
# 888         0       3  female   NaN    1.0      2  23.45        S  Third
# 889         1       1    male  26.0    0.0      0  30.00        C  First
# 890         0       3    male  32.0    0.0      0   7.75        Q  Third
# 891       892       3       2  male   23.1      0   5.56        Q  First
#
#        who adult_male deck  embark_town alive  alone  Total
# 887  woman      False    B  Southampton   yes   True      2
# 888  woman      False  NaN  Southampton    no  False      3
# 889    man       True    C    Cherbourg   yes   True      2
# 890    man       True  NaN   Queenstown    no   True      3
# 891    man       true  NAN  ffhkkdmfdrm    no   true      6

# %%
df.describe()
# Out:
#          survived      pclass       sibsp       parch        fare       Total
# count  892.000000  892.000000  892.000000  892.000000  892.000000  892.000000
# mean     1.383408    2.309417    0.548318    0.381166   32.174338    2.696188
# std     29.857478    0.835923    1.336456    0.805706   49.673546    0.819698
# min      0.000000    1.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    2.000000    0.000000    0.000000    7.895800    2.000000
# 50%      0.000000    3.000000    0.000000    0.000000   14.454200    3.000000
# 75%      1.000000    3.000000    1.000000    0.000000   31.000000    3.000000
# max    892.000000    3.000000   23.100000    6.000000  512.329200    6.000000

# %%
df["survived"].mean()
# Out:
# 1.383408071748879

# %%
df["survived"].median()
# Out:
# 0.0

# %%
df["survived"].mode()
# Out:
# 0    0
# Name: survived, dtype: int64

# %%
df.shape
# Out:
# (892, 16)

# %%
df["survived"].values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8536\1379155053.py in ?()
# ----> 1 df["survived"].values_counts()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'values_counts'
